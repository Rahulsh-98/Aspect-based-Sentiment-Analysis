# %%
import pandas as pd
import re
import string

# %%
def preprocess_text(text):
    # lowercase
    text = text.lower()
    # Removes URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # Removes punctuation and special characters
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Removes non-alphanumeric characters
    text = re.sub(r'\W+', ' ', text)
    return text.strip()

# %%
df_labeled = pd.read_csv('C:/Users/Devanand J/Desktop/SemEval_2014.csv')
df_unlabeled = pd.read_csv('C:/Users/Devanand J/Desktop/Yelp_2015.csv')

# Applying the above preprocessing step to the respective comments column
df_labeled['comments'] = df_labeled['comments'].apply(preprocess_text)
df_unlabeled['preprocessed_comments'] = df_unlabeled['preprocessed_comments'].apply(preprocess_text)

# Save the cleaned dataset (optional)
df_labeled.to_csv('C:/Users/Devanand J/Desktop/Final/SemEval_raw.csv', index=False)
df_unlabeled.to_csv('C:/Users/Devanand J/Desktop/Final/SemEval_raw.csv', index=False)

# Displaying first few rows of the cleaned labeled and unlabeled dataset
print(df_labeled.head())
print(df_unlabeled.head())
# Out:
#    overall polarity                                           comments
# 0                 1  unfortunately the frustration of being dr gold...
# 1                 2  been going to dr goldberg for over 10 years i ...
# 2                 1  i dont know what dr goldberg was like before m...
# 3                 1  im writing this review to give you a heads up ...
# 4                 2  all the food is great here but the best thing ...

# %%
# !pip install spacy
# !pip install neuralcoref
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\devanand j\appdata\roaming\python\python311\site-packages (3.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\devanand j\appdata\roaming\python\python311\site-packages (from spacy) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\devanand j\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in c:\users\devanand j\anaconda3\lib\site-packages (from pathy>=0.10.0->spacy) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\devanand j\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\devanand j\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\devanand j\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\devanand j\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\devanand j\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\devanand j\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\devanand j\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.1)
# Collecting neuralcoref
#   Downloading neuralcoref-4.0.tar.gz (368 kB)
#      ---------------------------------------- 0.0/368.7 kB ? eta -:--:--
#      - -------------------------------------- 10.2/368.7 kB ? eta -:--:--
#      ---- -------------------------------- 41.0/368.7 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------  368.6/368.7 kB 2.9 MB/s eta 0:00:01
#      -------------------------------------- 368.7/368.7 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.15.0 in c:\users\devanand j\anaconda3\lib\site-packages (from neuralcoref) (1.23.5)
# Collecting boto3 (from neuralcoref)
#   Downloading boto3-1.34.151-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\devanand j\anaconda3\lib\site-packages (from neuralcoref) (2.32.2)
# Requirement already satisfied: spacy>=2.1.0 in c:\users\devanand j\appdata\roaming\python\python311\site-packages (from neuralcoref) (3.5.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2024.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\devanand j\appdata\roaming\python\python311\site-packages (from spacy>=2.1.0->neuralcoref) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (4.66.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy>=2.1.0->neuralcoref) (3.4.0)
# Collecting botocore<1.35.0,>=1.34.151 (from boto3->neuralcoref)
#   Downloading botocore-1.34.151-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\devanand j\anaconda3\lib\site-packages (from boto3->neuralcoref) (1.0.1)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->neuralcoref)
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\devanand j\anaconda3\lib\site-packages (from botocore<1.35.0,>=1.34.151->boto3->neuralcoref) (2.9.0.post0)
# Requirement already satisfied: language-data>=1.2 in c:\users\devanand j\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy>=2.1.0->neuralcoref) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in c:\users\devanand j\anaconda3\lib\site-packages (from pathy>=0.10.0->spacy>=2.1.0->neuralcoref) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\devanand j\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=2.1.0->neuralcoref) (4.12.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\devanand j\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.1.0->neuralcoref) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\devanand j\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.1.0->neuralcoref) (0.1.4)
# Requirement already satisfied: colorama in c:\users\devanand j\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy>=2.1.0->neuralcoref) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\devanand j\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy>=2.1.0->neuralcoref) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\devanand j\anaconda3\lib\site-packages (from jinja2->spacy>=2.1.0->neuralcoref) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\devanand j\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=2.1.0->neuralcoref) (1.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\devanand j\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.151->boto3->neuralcoref) (1.16.0)
# Downloading boto3-1.34.151-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.2 kB ? eta -:--:--
#    ---------------------------------------- 139.2/139.2 kB ? eta 0:00:00
# Downloading botocore-1.34.151-py3-none-any.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.4 MB 15.9 MB/s eta 0:00:01
#    ------ --------------------------------- 1.9/12.4 MB 20.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.2/12.4 MB 23.1 MB/s eta 0:00:01
#    --------------- ------------------------ 4.8/12.4 MB 25.4 MB/s eta 0:00:01
#    ------------------- -------------------- 6.0/12.4 MB 25.8 MB/s eta 0:00:01
#    ------------------------ --------------- 7.6/12.4 MB 27.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.4 MB 28.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.6/12.4 MB 29.7 MB/s eta 0:00:01
#    -------------------------------------- - 12.0/12.4 MB 31.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 28.5 MB/s eta 0:00:00
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.7 kB ? eta -:--:--
#    ---------------------------------------- 82.7/82.7 kB ? eta 0:00:00
# Building wheels for collected packages: neuralcoref
#   Building wheel for neuralcoref (setup.py): started
#   Building wheel for neuralcoref (setup.py): finished with status 'error'
#   Running setup.py clean for neuralcoref
# Failed to build neuralcoref
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [35 lines of output]
#   C:\Users\Devanand J\anaconda3\Lib\site-packages\setuptools\__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
#           ********************************************************************************
#
#   !!
#     dist.fetch_build_eggs(dist.setup_requires)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-311
#   creating build\lib.win-amd64-cpython-311\neuralcoref
#   copying neuralcoref\file_utils.py -> build\lib.win-amd64-cpython-311\neuralcoref
#   copying neuralcoref\__init__.py -> build\lib.win-amd64-cpython-311\neuralcoref
#   creating build\lib.win-amd64-cpython-311\neuralcoref\tests
#   copying neuralcoref\tests\test_neuralcoref.py -> build\lib.win-amd64-cpython-311\neuralcoref\tests
#   copying neuralcoref\tests\__init__.py -> build\lib.win-amd64-cpython-311\neuralcoref\tests
#   creating build\lib.win-amd64-cpython-311\neuralcoref\train
#   copying neuralcoref\train\algorithm.py -> build\lib.win-amd64-cpython-311\neuralcoref\train
#   copying neuralcoref\train\compat.py -> build\lib.win-amd64-cpython-311\neuralcoref\train
#   copying neuralcoref\train\conllparser.py -> build\lib.win-amd64-cpython-311\neuralcoref\train
#   copying neuralcoref\train\dataset.py -> build\lib.win-amd64-cpython-311\neuralcoref\train
#   copying neuralcoref\train\document.py -> build\lib.win-amd64-cpython-311\neuralcoref\train
#   copying neuralcoref\train\evaluator.py -> build\lib.win-amd64-cpython-311\neuralcoref\train
#   copying neuralcoref\train\learn.py -> build\lib.win-amd64-cpython-311\neuralcoref\train
#   copying neuralcoref\train\model.py -> build\lib.win-amd64-cpython-311\neuralcoref\train
#   copying neuralcoref\train\utils.py -> build\lib.win-amd64-cpython-311\neuralcoref\train
#   copying neuralcoref\train\__init__.py -> build\lib.win-amd64-cpython-311\neuralcoref\train
#   running build_ext
#   building 'neuralcoref.neuralcoref' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for neuralcoref
# ERROR: Could not build wheels for neuralcoref, which is required to install pyproject.toml-based projects
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 660.6 kB/s eta 0:00:20
#      - -------------------------------------- 0.5/12.8 MB 4.4 MB/s eta 0:00:03
#      ------ --------------------------------- 2.1/12.8 MB 13.1 MB/s eta 0:00:01
#      --------- ------------------------------ 2.9/12.8 MB 15.5 MB/s eta 0:00:01
#      --------------- ------------------------ 5.0/12.8 MB 21.1 MB/s eta 0:00:01
#      ------------------- -------------------- 6.1/12.8 MB 21.6 MB/s eta 0:00:01
#      ------------------------- -------------- 8.0/12.8 MB 24.5 MB/s eta 0:00:01
#      ------------------------------ --------- 9.9/12.8 MB 26.3 MB/s eta 0:00:01
#      ------------------------------------ -- 11.9/12.8 MB 36.4 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 38.6 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 32.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\devanand j\appdata\roaming\python\python311\site-packages (from en-core-web-sm==3.5.0) (3.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\devanand j\appdata\roaming\python\python311\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.66.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\devanand j\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\devanand j\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in c:\users\devanand j\anaconda3\lib\site-packages (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\devanand j\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devanand j\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\devanand j\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\devanand j\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\devanand j\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\devanand j\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\devanand j\anaconda3\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\devanand j\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import spacy
import neuralcoref


nlp = spacy.load("en_core_web_sm")

# Adding neuralcoref to the spaCy pipeline
neuralcoref.add_to_pipe(nlp)
df_labeled = pd.read_csv('C:/Users/Devanand J/Desktop/Final/SemEval_raw.csv')
df_unlabeled = pd.read_csv('C:/Users/Devanand J/Desktop/Final/Yelp_dataset_raw.csv')

# To handle the non empty string errors
df_labeled['comments'] = df_labeled['comments'].astype(str)
df_unlabeled['preprocessed_comments'] = df_unlabeled['preprocessed_comments'].astype(str)

# POS tagging, syntactic parsing, and coreference resolution
def preprocess_text_spacy(text):
    doc = nlp(text)
    tokens = [(token.text, token.pos_, token.dep_) for token in doc]
    coreferences = []
    if doc._.has_coref:
        for cluster in doc._.coref_clusters:
            main_mention = cluster.main
            for mention in cluster.mentions:
                coreferences.append((mention.text, mention.start, mention.end, main_mention.text))
    return tokens, coreferences

df_labeled['spacy_analysis'] = df_labeled['comments'].apply(preprocess_text_spacy)
df_unlabeled['spacy_analysis'] = df_unlabeled['preprocessed_comments'].apply(preprocess_text_spacy)
df_labeled.to_csv('C:/Users/Devanand J/Desktop/Final/Subset2000/SemEval.csv', index=False)
df_unlabeled.to_csv('C:/Users/Devanand J/Desktop/Final/Subset2000/Yelp_dataset.csv', index=False)

# Printing the first few rows
print("Processed Labeled Dataset:")
print(df_labeled.head().to_string())
print("\nProcessed Unlabeled Dataset:")
print(df_unlabeled.head().to_string())
# Out:
# Processed Labeled Dataset:
#                                             comments                                      spacy_analysis
# 0      The food was great, but the service was slow.  ([('The', 'DET', 'det'), ('food', 'NOUN', 'nsubj'), ('was', 'AUX', 'ROOT'), ('great', 'ADJ', 'acomp'), (',', 'PUNCT', 'punct'), ('but', 'CCONJ', 'cc'), ('the', 'DET', 'det'), ('service', 'NOUN', 'nsubj'), ('was', 'AUX', 'conj'), ('slow', 'ADJ', 'acomp'), ('.', 'PUNCT', 'punct')], [('The food', 0, 2, 'The food'), ('the service', 6, 8, 'the service')])
# 1  I loved the ambiance and the staff was very fr...  ([('I', 'PRON', 'nsubj'), ('loved', 'VERB', 'ROOT'), ('the', 'DET', 'det'), ('ambiance', 'NOUN', 'dobj'), ('and', 'CCONJ', 'cc'), ('the', 'DET', 'det'), ('staff', 'NOUN', 'nsubj'), ('was', 'AUX', 'ROOT'), ('very', 'ADV', 'advmod'), ('friendly', 'ADJ', 'acomp'), ('.', 'PUNCT', 'punct')], [('I', 0, 1, 'I'), ('the staff', 5, 7, 'the staff')])
# 2  The prices are reasonable and the portions are...  ([('The', 'DET', 'det'), ('prices', 'NOUN', 'nsubj'), ('are', 'AUX', 'ROOT'), ('reasonable', 'ADJ', 'acomp'), ('and', 'CCONJ', 'cc'), ('the', 'DET', 'det'), ('portions', 'NOUN', 'nsubj'), ('are', 'AUX', 'conj'), ('generous', 'ADJ', 'acomp'), ('.', 'PUNCT', 'punct')], [('The prices', 0, 2, 'The prices'), ('the portions', 5, 7, 'the portions')])
# 3  The food was awful and the place was dirty. Ne...  ([('The', 'DET', 'det'), ('food', 'NOUN', 'nsubj'), ('was', 'AUX', 'ROOT'), ('awful', 'ADJ', 'acomp'), ('and', 'CCONJ', 'cc'), ('the', 'DET', 'det'), ('place', 'NOUN', 'nsubj'), ('was', 'AUX', 'conj'), ('dirty', 'ADJ', 'acomp'), ('.', 'PUNCT', 'punct'), ('Never', 'ADV', 'advmod'), ('coming', 'VERB', 'advcl'), ('back', 'ADV', 'advmod'), ('!', 'PUNCT', 'punct')], [('The food', 0, 2, 'The food'), ('the place', 6, 8, 'the place')])
# 4  The desserts were fantastic! Highly recommend ...  ([('The', 'DET', 'det'), ('desserts', 'NOUN', 'nsubj'), ('were', 'AUX', 'ROOT'), ('fantastic', 'ADJ', 'acomp'), ('!', 'PUNCT', 'punct'), ('Highly', 'ADV', 'advmod'), ('recommend', 'VERB', 'ROOT'), ('this', 'DET', 'det'), ('place', 'NOUN', 'dobj'), ('.', 'PUNCT', 'punct')], [('The desserts', 0, 2, 'The desserts'), ('this place', 7, 9, 'this place')])
#
#
# Processed Unlabeled Dataset:
#                                 preprocessed_comments                                      spacy_analysis
# 0       Great place to hang out with friends.  ([('Great', 'ADJ', 'amod'), ('place', 'NOUN', 'nsubj'), ('to', 'PART', 'aux'), ('hang', 'VERB', 'xcomp'), ('out', 'PART', 'prt'), ('with', 'ADP', 'prep'), ('friends', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')], [('Great place', 0, 2, 'Great place')])
# 1  The pizza was delicious, but the wait time was...  ([('The', 'DET', 'det'), ('pizza', 'NOUN', 'nsubj'), ('was', 'AUX', 'ROOT'), ('delicious', 'ADJ', 'acomp'), (',', 'PUNCT', 'punct'), ('but', 'CCONJ', 'cc'), ('the', 'DET', 'det'), ('wait', 'NOUN', 'nsubj'), ('time', 'NOUN', 'compound'), ('was', 'AUX', 'conj'), ('too', 'ADV', 'advmod'), ('long', 'ADJ', 'acomp'), ('.', 'PUNCT', 'punct')], [('The pizza', 0, 2, 'The pizza'), ('the wait time', 6, 9, 'the wait time')])
# 2  I wouldn't recommend this place to anyone.  ([('I', 'PRON', 'nsubj'), ("wouldn't", 'VERB', 'aux'), ('recommend', 'VERB', 'ROOT'), ('this', 'DET', 'det'), ('place', 'NOUN', 'dobj'), ('to', 'ADP', 'prep'), ('anyone', 'NOUN', 'pobj'), ('.', 'PUNCT', 'punct')], [('I', 0, 1, 'I'), ('this place', 3, 5, 'this place')])
# 3  The decor was beautiful, but the food was tast...  ([('The', 'DET', 'det'), ('decor', 'NOUN', 'nsubj'), ('was', 'AUX', 'ROOT'), ('beautiful', 'ADJ', 'acomp'), (',', 'PUNCT', 'punct'), ('but', 'CCONJ', 'cc'), ('the', 'DET', 'det'), ('food', 'NOUN', 'nsubj'), ('was', 'AUX', 'conj'), ('tasteless', 'ADJ', 'acomp'), ('.', 'PUNCT', 'punct')], [('The decor', 0, 2, 'The decor'), ('the food', 6, 8, 'the food')])
# 4  Excellent service and friendly staff.  ([('Excellent', 'ADJ', 'amod'), ('service', 'NOUN', 'nsubj'), ('and', 'CCONJ', 'cc'), ('friendly', 'ADJ', 'amod'), ('staff', 'NOUN', 'conj'), ('.', 'PUNCT', 'punct')], [('Excellent service', 0, 2, 'Excellent service'), ('friendly staff', 3, 5, 'friendly staff')])
